# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Columns**
# - A. transaction_id
# - B. transaction_date
# - C. transaction_time
# - D. transaction_qty
# - E. store_id
# - F. store_location
# - G. product_id
# - H. unit_price
# - I. product_category
# - J. product_type
# - K. product_detail

# %% [markdown]
# - Revenue =H2*D2
# - Month	=MONTH(B2)
# - Month name =TEXT(B2,"mmm")
# - Weekday =WEEKDAY(B2,2)
# - Weekday name	=TEXT(B2,"ddd")
# - Hour =HOUR(C2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Drag and drop of all these columns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Answer**

# %% [markdown]
# ![image.png](attachment:image.png)
